# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',20)

# %%
df1 = pd.read_csv("usdiseases.csv")

# %%
df1
# Out:
#            disease    state  year  weeks_reporting  count  population
# 0      Hepatitis A  Alabama  1966               50    321   3345787.0
# 1      Hepatitis A  Alabama  1967               49    291   3364130.0
# 2      Hepatitis A  Alabama  1968               52    314   3386068.0
# 3      Hepatitis A  Alabama  1969               49    380   3412450.0
# 4      Hepatitis A  Alabama  1970               51    413   3444165.0
# ...            ...      ...   ...              ...    ...         ...
# 16060     Smallpox  Wyoming  1948               24      1    280803.0
# 16061     Smallpox  Wyoming  1949                0      0    285544.0
# 16062     Smallpox  Wyoming  1950                1      2    290529.0
# 16063     Smallpox  Wyoming  1951                1      1    295744.0
# 16064     Smallpox  Wyoming  1952                1      1    301083.0
#
# [16065 rows x 6 columns]

# %%
df2 = pd.read_csv("murders.csv")

# %%
df2
# Out:
#             state abb         region  population  total
# 0         Alabama  AL          South     4779736    135
# 1          Alaska  AK           West      710231     19
# 2         Arizona  AZ           West     6392017    232
# 3        Arkansas  AR          South     2915918     93
# 4      California  CA           West    37253956   1257
# ..            ...  ..            ...         ...    ...
# 46       Virginia  VA          South     8001024    250
# 47     Washington  WA           West     6724540     93
# 48  West Virginia  WV          South     1852994     27
# 49      Wisconsin  WI  North Central     5686986     97
# 50        Wyoming  WY           West      563626      5
#
# [51 rows x 5 columns]

# %%
#Make a box plot of the murder rates by region
plt.figure(figsize=(10,10))
sns.boxplot(x='region',y="total", data=df2);
