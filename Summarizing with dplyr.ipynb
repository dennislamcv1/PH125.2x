# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',20)

# %%
df = pd.read_csv("NHANES.csv")

# %%
df
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths    Race1    Race3  \
# 0     51624  2009_10    male   34     30-39      409.0    White      NaN
# 1     51624  2009_10    male   34     30-39      409.0    White      NaN
# 2     51624  2009_10    male   34     30-39      409.0    White      NaN
# 3     51625  2009_10    male    4       0-9       49.0    Other      NaN
# 4     51630  2009_10  female   49     40-49      596.0    White      NaN
# ...     ...      ...     ...  ...       ...        ...      ...      ...
# 9995  71909  2011_12    male   28     20-29        NaN  Mexican  Mexican
# 9996  71910  2011_12  female    0       0-9        5.0    White    White
# 9997  71911  2011_12    male   27     20-29        NaN  Mexican  Mexican
# 9998  71915  2011_12    male   60     60-69        NaN    White    White
# 9999  71915  2011_12    male   60     60-69        NaN    White    White
#
#            Education MaritalStatus     HHIncome  HHIncomeMid  Poverty  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 76 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                10000 non-null  int64
#  1   SurveyYr          10000 non-null  object
#  2   Gender            10000 non-null  object
#  3   Age               10000 non-null  int64
#  4   AgeDecade         9667 non-null   object
#  5   AgeMonths         4962 non-null   float64
#  6   Race1             10000 non-null  object
#  7   Race3             5000 non-null   object
#  8   Education         7221 non-null   object
#  9   MaritalStatus     7231 non-null   object
#  10  HHIncome          9189 non-null   object
#  11  HHIncomeMid       9189 non-null   float64
#  12  Poverty           9274 non-null   float64
#  13  HomeRooms         9931 non-null   float64
#  14  HomeOwn           9937 non-null   object
#  15  Work              7771 non-null   object
# ...

# %%
#Filter the NHANES dataset so that only 20-29 year old females are included and assign this new data frame to the object tab
females = df[df['Gender'] == 'female']
females
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths    Race1    Race3  \
# 4     51630  2009_10  female   49     40-49      596.0    White      NaN
# 7     51647  2009_10  female   45     40-49      541.0    White      NaN
# 8     51647  2009_10  female   45     40-49      541.0    White      NaN
# 9     51647  2009_10  female   45     40-49      541.0    White      NaN
# 13    51659  2009_10  female   10     10-19      123.0    White      NaN
# ...     ...      ...     ...  ...       ...        ...      ...      ...
# 9986  71882  2011_12  female   60     60-69        NaN    Black    Black
# 9987  71898  2011_12  female   65     60-69        NaN  Mexican  Mexican
# 9991  71908  2011_12  female   66     60-69        NaN    White    White
# 9992  71908  2011_12  female   66     60-69        NaN    White    White
# 9996  71910  2011_12  female    0       0-9        5.0    White    White
#
#            Education MaritalStatus     HHIncome  HHIncomeMid  Poverty  \
# ...

# %%
females['AgeDecade']
# Out:
# 4        40-49
# 7        40-49
# 8        40-49
# 9        40-49
# 13       10-19
#          ...
# 9986     60-69
# 9987     60-69
# 9991     60-69
# 9992     60-69
# 9996       0-9
# Name: AgeDecade, Length: 5020, dtype: object

# %%
females['AgeDecade'].unique()
# Out:
# array([' 40-49', ' 10-19', ' 50-59', ' 0-9', ' 60-69', ' 20-29', ' 30-39',
#        ' 70+', nan], dtype=object)

# %%
tab = females[females['AgeDecade'] == ' 20-29']
tab
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths     Race1    Race3  \
# 31    51710  2009_10  female   26     20-29      319.0     White      NaN
# 46    51731  2009_10  female   28     20-29      346.0     Black      NaN
# 49    51741  2009_10  female   21     20-29      253.0     Black      NaN
# 50    51741  2009_10  female   21     20-29      253.0     Black      NaN
# 62    51760  2009_10  female   27     20-29      334.0  Hispanic      NaN
# ...     ...      ...     ...  ...       ...        ...       ...      ...
# 9882  71679  2011_12  female   27     20-29        NaN   Mexican  Mexican
# 9907  71740  2011_12  female   20     20-29        NaN     Black    Black
# 9910  71745  2011_12  female   21     20-29        NaN     White    White
# 9932  71784  2011_12  female   24     20-29        NaN     White    White
# 9982  71873  2011_12  female   20     20-29        NaN     White    White
#
#            Education MaritalStatus     HHIncome  HHIncomeMid  Poverty  \
# ...

# %%
#Complete the line of code to save the average and standard deviation of systolic blood pressure as average and standard_deviation to a variable called ref
ref = tab.describe()
ref
# Out:
#                  ID         Age   AgeMonths    HHIncomeMid     Poverty  \
# count    681.000000  681.000000  335.000000     614.000000  630.000000
# mean   62024.046990   24.543319  301.104478   48184.039088    2.222952
# std     5918.568542    2.820349   34.316567   32349.859083    1.627395
# min    51710.000000   20.000000  240.000000    2500.000000    0.000000
# 25%    56684.000000   22.000000  272.000000   17500.000000    0.820000
# 50%    62415.000000   25.000000  301.000000   40000.000000    1.740000
# 75%    66964.000000   27.000000  329.000000   87500.000000    3.400000
# max    71873.000000   29.000000  358.000000  100000.000000    5.000000
#
#         HomeRooms      Weight  Length  HeadCirc      Height         BMI  \
# count  670.000000  678.000000     0.0       0.0  678.000000  678.000000
# mean     5.286567   73.266667     NaN       NaN  163.127286   27.513555
# std      1.987622   21.040247     NaN       NaN    7.131291    7.681940
# ...

# %%
#Report te min and max values for the same group as in the previous exercises
tab['BPSysAve'].min()
# Out:
# 84.0

# %%
tab['BPSysAve'].max()
# Out:
# 179.0

# %%
#compute the average and standard deviation of systolic blood pressure for females for each age group separately
tab.groupby(by='AgeDecade').mean()
# Out:
#                     ID        Age   AgeMonths   HHIncomeMid   Poverty  \
# AgeDecade
#  20-29     62024.04699  24.543319  301.104478  48184.039088  2.222952
#
#            HomeRooms     Weight  Length  HeadCirc      Height        BMI  \
# AgeDecade
#  20-29      5.286567  73.266667     NaN       NaN  163.127286  27.513555
#
#                Pulse    BPSysAve  BPDiaAve      BPSys1     BPDia1      BPSys2  \
# AgeDecade
#  20-29     77.003067  108.422427  65.41321  109.065811  65.168539  108.664587
#
#               BPDia2      BPSys3     BPDia3  Testosterone  DirectChol  \
# AgeDecade
#  20-29     64.957878  108.235479  65.503925     30.635884    1.405905
#
#             TotChol   UrineVol1  UrineFlow1   UrineVol2  UrineFlow2  \
# AgeDecade
#  20-29     4.587492  109.245536    0.921731  124.670807    1.247957
#
#            DiabetesAge  DaysPhysHlthBad  DaysMentHlthBad  nPregnancies  \
# AgeDecade
#  20-29            19.0         2.641608         5.624126      2.068841
#
# ...

# %%
tab.groupby(by='AgeDecade').std()
# Out:
#                     ID       Age  AgeMonths   HHIncomeMid   Poverty  \
# AgeDecade
#  20-29     5918.568542  2.820349  34.316567  32349.859083  1.627395
#
#            HomeRooms     Weight  Length  HeadCirc    Height      BMI  \
# AgeDecade
#  20-29      1.987622  21.040247     NaN       NaN  7.131291  7.68194
#
#                Pulse   BPSysAve  BPDiaAve    BPSys1    BPDia1     BPSys2  \
# AgeDecade
#  20-29     11.240425  10.146681  10.03163  9.745665  9.444141  10.407396
#
#               BPDia2     BPSys3     BPDia3  Testosterone  DirectChol  \
# AgeDecade
#  20-29     10.410921  10.290183  10.252415     16.579334    0.358596
#
#             TotChol  UrineVol1  UrineFlow1  UrineVol2  UrineFlow2  \
# AgeDecade
#  20-29     0.893926  87.612312    0.937672  96.398961    1.397024
#
#            DiabetesAge  DaysPhysHlthBad  DaysMentHlthBad  nPregnancies  \
# AgeDecade
#  20-29        4.358899         6.308131         8.551706      1.181204
#
# ...

# %%
#Create a single summary table for the average and standard deviation of systolic blood pressure using group_by(AgeDecade, Gender)
df.groupby('BPSysAve').mean()
# Out:
#                ID   Age  AgeMonths  HHIncomeMid  Poverty  HomeRooms  Weight  \
# BPSysAve
# 76.0      53661.0  12.0     145.00      87500.0    4.230       7.00  94.900
# 78.0      58821.0  51.0     613.00       2500.0    0.000       7.00  46.600
# 79.0      67253.0  10.0        NaN      70000.0    2.910       6.00  31.300
# 80.0      54896.0  57.5     692.75      54375.0    3.080       6.75  81.575
# 81.0      68237.0  37.5        NaN      33750.0    1.525       3.50  62.050
# ...           ...   ...        ...          ...      ...        ...     ...
# 210.0     58276.0  80.0        NaN      40000.0    2.750       5.00  53.000
# 212.0     53371.0  68.0     817.00      12500.0    1.290       5.00  57.800
# 217.0     62727.0  80.0        NaN      30000.0    1.650       5.00  78.200
# 221.0     67957.0  50.0        NaN          NaN      NaN       5.00  56.200
# 226.0     55311.0  55.0     671.00      30000.0    0.850       5.00  67.800
#
# ...

# %%
df.groupby('BPSysAve').std()
# Out:
#                    ID       Age   AgeMonths   HHIncomeMid   Poverty  \
# BPSysAve
# 76.0              NaN       NaN         NaN           NaN       NaN
# 78.0              NaN       NaN         NaN           NaN       NaN
# 79.0              NaN       NaN         NaN           NaN       NaN
# 80.0      2939.553027  33.12099  393.845465  22580.873175  1.352997
# 81.0       680.271416  27.93385         NaN  17800.983119  0.783243
# ...               ...       ...         ...           ...       ...
# 210.0             NaN       NaN         NaN           NaN       NaN
# 212.0             NaN       NaN         NaN           NaN       NaN
# 217.0        0.000000   0.00000         NaN      0.000000  0.000000
# 221.0        0.000000   0.00000         NaN           NaN       NaN
# 226.0             NaN       NaN         NaN           NaN       NaN
#
#           HomeRooms     Weight  Length  HeadCirc     Height        BMI  \
# BPSysAve
# ...

# %%
#Compute the average and standard deviation for each value of Race1
df.groupby('Race1').mean()
# Out:
#                     ID        Age   AgeMonths   HHIncomeMid   Poverty  \
# Race1
# Black     61846.981621  33.944862  399.781199  41559.266228  2.035522
# Hispanic  62785.191803  31.726230  367.674157  46831.775701  2.020490
# Mexican   61738.305419  27.376355  323.808318  39424.829157  1.665660
# Other     62440.968983  32.290323  366.548649  58662.464986  2.742319
# White     61852.610326  39.802731  451.705864  63333.055509  3.186686
#
#           HomeRooms     Weight     Length   HeadCirc      Height        BMI  \
# Race1
# Black      5.640940  74.717968  87.547692  39.085714  161.327869  28.102355
# Hispanic   5.359143  65.727258  88.300000  40.150000  156.242615  26.373396
# Mexican    5.116000  64.788679  84.215054  40.918750  155.378497  26.502432
# Other      5.763158  62.127625  85.050909  41.336364  157.039075  24.432674
# White      6.688664  72.893127  84.189161  41.550000  164.140938  26.722153
#
# ...

# %%
df.groupby('Race1').std()
# Out:
#                    ID        Age   AgeMonths   HHIncomeMid   Poverty  \
# Race1
# Black     5776.075627  21.572162  257.569198  30385.110807  1.547479
# Hispanic  5598.990243  20.545088  225.158563  31465.600378  1.541092
# Mexican   5996.935901  19.178396  228.630991  26679.546843  1.298076
# Other     5902.772859  20.914676  236.973554  33472.689964  1.678971
# White     5882.018445  22.717185  263.291603  32315.293365  1.612025
#
#           HomeRooms     Weight     Length  HeadCirc     Height       BMI  \
# Race1
# Black      1.912951  33.115550  14.078464  3.443074  20.828688  9.099617
# Hispanic   2.088672  27.735540  12.612858  1.909188  20.399261  6.954574
# Mexican    1.716243  29.263420  13.613739  2.758313  21.953514  6.970077
# Other      2.069749  27.245106  14.132310  1.636015  22.226223  6.595646
# White      2.335105  28.226841  13.674781  2.018881  19.020477  7.136690
#
#               Pulse   BPSysAve   BPDiaAve     BPSys1     BPDia1     BPSys2  \
# Race1
# ...
