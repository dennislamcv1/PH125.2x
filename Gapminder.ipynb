# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',20)

# %%
df = pd.read_csv("gapminder.csv")

# %%
df
# Out:
#                    country  year  infant_mortality  life_expectancy  \
# 0                  Albania  1960            115.40            62.87
# 1                  Algeria  1960            148.20            47.50
# 2                   Angola  1960            208.00            35.98
# 3      Antigua and Barbuda  1960               NaN            62.97
# 4                Argentina  1960             59.87            65.39
# ...                    ...   ...               ...              ...
# 10540   West Bank and Gaza  2016               NaN            74.70
# 10541              Vietnam  2016               NaN            75.60
# 10542                Yemen  2016               NaN            64.92
# 10543               Zambia  2016               NaN            57.10
# 10544             Zimbabwe  2016               NaN            61.69
#
#        fertility  population           gdp continent              region
# 0           6.19   1636054.0           NaN    Europe     Southern Europe
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10545 entries, 0 to 10544
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           10545 non-null  object
#  1   year              10545 non-null  int64
#  2   infant_mortality  9092 non-null   float64
#  3   life_expectancy   10545 non-null  float64
#  4   fertility         10358 non-null  float64
#  5   population        10360 non-null  float64
#  6   gdp               7573 non-null   float64
#  7   continent         10545 non-null  object
#  8   region            10545 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 741.6+ KB

# %%
df['continent'].unique()
# Out:
# array(['Europe', 'Africa', 'Americas', 'Asia', 'Oceania'], dtype=object)

# %%
africa = df[df['continent'] == 'Africa']
africa
# Out:
#             country  year  infant_mortality  life_expectancy  fertility  \
# 1           Algeria  1960             148.2            47.50       7.65
# 2            Angola  1960             208.0            35.98       7.32
# 17            Benin  1960             186.9            38.29       6.28
# 21         Botswana  1960             115.5            50.34       6.62
# 25     Burkina Faso  1960             161.3            35.21       6.29
# ...             ...   ...               ...              ...        ...
# 10525          Togo  2016               NaN            61.90        NaN
# 10528       Tunisia  2016               NaN            77.60        NaN
# 10531        Uganda  2016               NaN            61.91        NaN
# 10543        Zambia  2016               NaN            57.10        NaN
# 10544      Zimbabwe  2016               NaN            61.69        NaN
#
#        population           gdp continent           region
# ...

# %%
africa['year'].unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016], dtype=int64)

# %%
year2012africa = africa[africa['year'] == 2012]
year2012africa
# Out:
#            country  year  infant_mortality  life_expectancy  fertility  \
# 9621       Algeria  2012              22.4             76.2       2.82
# 9622        Angola  2012             104.1             58.5       5.98
# 9637         Benin  2012              68.5             61.4       4.93
# 9641      Botswana  2012              38.2             56.5       2.67
# 9645  Burkina Faso  2012              65.4             59.9       5.69
# ...            ...   ...               ...              ...        ...
# 9785          Togo  2012              56.5             60.3       4.70
# 9788       Tunisia  2012              13.6             77.4       2.02
# 9791        Uganda  2012              42.5             59.3       5.96
# 9803        Zambia  2012              49.0             54.7       5.73
# 9804      Zimbabwe  2012              49.4             54.2       3.56
#
#       population  gdp continent           region
# 9621  37439427.0  NaN    Africa  Northern Africa
# ...

# %%
#create a scatter plot of life expectancy versus fertility for the African continent in 2012
plt.figure(figsize=(10,10))
sns.scatterplot(x='life_expectancy', y='fertility', data=year2012africa);

# %%
#Remake the plot from the previous exercises but this time use color to distinguish the different regions of Africa to see if this explains the clusters. 
plt.figure(figsize=(10,10))
sns.scatterplot(x='life_expectancy', y='fertility', data=year2012africa, hue='region');

# %%
#Create a table showing the country and region for the African countries (use select) that in 2012 had fertility rates of 3 or less and life expectancies of at least 70.
table = year2012africa[(year2012africa['fertility']<3) & (year2012africa['life_expectancy']>70)]
table
# Out:
#          country  year  infant_mortality  life_expectancy  fertility  \
# 9621     Algeria  2012              22.4             76.2       2.82
# 9650  Cape Verde  2012              22.4             71.9       2.33
# 9669       Egypt  2012              22.6             70.5       2.81
# 9717       Libya  2012              12.9             75.5       2.41
# 9729   Mauritius  2012              12.8             74.1       1.50
# 9735     Morocco  2012              26.4             74.1       2.71
# 9766  Seychelles  2012              12.2             73.7       2.21
# 9788     Tunisia  2012              13.6             77.4       2.02
#
#       population  gdp continent           region
# 9621  37439427.0  NaN    Africa  Northern Africa
# 9650    500870.0  NaN    Africa   Western Africa
# 9669  85660902.0  NaN    Africa  Northern Africa
# 9717   6283403.0  NaN    Africa  Northern Africa
# 9729   1258335.0  NaN    Africa   Eastern Africa
# ...

# %%
#Use filter to create a table with data for the years from 1960 to 2010 in Vietnam and the United States.
tab = df[(df['year'] < 2011) & (df['country'] == 'Vietnam') | (df['country'] == 'United States')]
tab
# Out:
#              country  year  infant_mortality  life_expectancy  fertility  \
# 175    United States  1960              25.9            69.91       3.67
# 181          Vietnam  1960              75.6            58.52       6.35
# 360    United States  1961              25.4            70.32       3.63
# 366          Vietnam  1961              72.6            59.17       6.39
# 545    United States  1962              24.9            70.21       3.48
# ...              ...   ...               ...              ...        ...
# 9795   United States  2012               6.1            79.00       1.90
# 9980   United States  2013               5.9            79.10       1.98
# 10165  United States  2014               5.7            79.10       1.97
# 10350  United States  2015               5.6            79.10       1.97
# 10535  United States  2016               NaN            79.10        NaN
#
#         population           gdp continent              region
# ...

# %%
#plot life expectancy vs year for Vietnam and the United States and save the plot as p
plt.figure(figsize=(10,10))
sns.lineplot(x='country', y='year', data=tab);

# %%
#create a dollars_per_day variable, which is defined as gdp/population/365.
africa
# Out:
#             country  year  infant_mortality  life_expectancy  fertility  \
# 1           Algeria  1960             148.2            47.50       7.65
# 2            Angola  1960             208.0            35.98       7.32
# 17            Benin  1960             186.9            38.29       6.28
# 21         Botswana  1960             115.5            50.34       6.62
# 25     Burkina Faso  1960             161.3            35.21       6.29
# ...             ...   ...               ...              ...        ...
# 10525          Togo  2016               NaN            61.90        NaN
# 10528       Tunisia  2016               NaN            77.60        NaN
# 10531        Uganda  2016               NaN            61.91        NaN
# 10543        Zambia  2016               NaN            57.10        NaN
# 10544      Zimbabwe  2016               NaN            61.69        NaN
#
#        population           gdp continent           region
# ...

# %%
africa['dollars_per_day'] = (africa['gdp'])/(africa['population'])/365
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
africa
# Out:
#             country  year  infant_mortality  life_expectancy  fertility  \
# 1           Algeria  1960             148.2            47.50       7.65
# 2            Angola  1960             208.0            35.98       7.32
# 17            Benin  1960             186.9            38.29       6.28
# 21         Botswana  1960             115.5            50.34       6.62
# 25     Burkina Faso  1960             161.3            35.21       6.29
# ...             ...   ...               ...              ...        ...
# 10525          Togo  2016               NaN            61.90        NaN
# 10528       Tunisia  2016               NaN            77.60        NaN
# 10531        Uganda  2016               NaN            61.91        NaN
# 10543        Zambia  2016               NaN            57.10        NaN
# 10544      Zimbabwe  2016               NaN            61.69        NaN
#
#        population           gdp continent           region  dollars_per_day
# ...

# %%
africa.dropna(inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
africa
# Out:
#            country  year  infant_mortality  life_expectancy  fertility  \
# 1          Algeria  1960             148.2            47.50       7.65
# 17           Benin  1960             186.9            38.29       6.28
# 21        Botswana  1960             115.5            50.34       6.62
# 25    Burkina Faso  1960             161.3            35.21       6.29
# 26         Burundi  1960             145.1            40.58       6.95
# ...            ...   ...               ...              ...        ...
# 9600          Togo  2011              57.9            59.60       4.75
# 9603       Tunisia  2011              14.2            77.20       2.04
# 9606        Uganda  2011              46.3            58.60       6.06
# 9618        Zambia  2011              51.1            53.70       5.77
# 9619      Zimbabwe  2011              54.0            51.60       3.64
#
#       population           gdp continent           region  dollars_per_day
# ...

# %%
#Create the dollars_per_day variable for African countries for the year 2010.
daydollars2010 = africa[africa['year'] == 2010]

# %%
daydollars2010
# Out:
#            country  year  infant_mortality  life_expectancy  fertility  \
# 9251       Algeria  2010              23.5             76.0       2.82
# 9252        Angola  2010             109.6             57.6       6.22
# 9267         Benin  2010              71.0             60.8       5.10
# 9271      Botswana  2010              39.8             55.6       2.76
# 9275  Burkina Faso  2010              69.7             59.0       5.87
# ...            ...   ...               ...              ...        ...
# 9415          Togo  2010              59.3             58.7       4.79
# 9418       Tunisia  2010              14.9             77.1       2.04
# 9421        Uganda  2010              49.5             57.8       6.16
# 9433        Zambia  2010              52.9             53.1       5.81
# 9434      Zimbabwe  2010              55.8             49.1       3.72
#
#       population           gdp continent           region  dollars_per_day
# ...

# %%
#Create a smooth density plot of dollars per day from daydollars
plt.figure(figsize=(10,10))
sns.distplot(a=daydollars2010.dollars_per_day, hist=False);

# %%
#Create the dollars_per_day variable for African countries for the year 2010.
daydollars1970 = africa[africa['year'] == 1970]

# %%
daydollars1970
# Out:
#            country  year  infant_mortality  life_expectancy  fertility  \
# 1851       Algeria  1970             146.0            52.41       7.64
# 1867         Benin  1970             157.1            43.93       6.75
# 1871      Botswana  1970              85.3            54.30       6.64
# 1875  Burkina Faso  1970             149.3            40.27       6.62
# 1876       Burundi  1970             146.4            42.76       7.31
# ...            ...   ...               ...              ...        ...
# 2007     Swaziland  1970             119.3            48.79       6.88
# 2015          Togo  1970             132.8            47.72       7.08
# 2018       Tunisia  1970             122.2            52.94       6.44
# 2033        Zambia  1970             109.3            53.88       7.44
# 2034      Zimbabwe  1970              72.4            57.22       7.42
#
#       population           gdp continent           region  dollars_per_day
# ...

# %%
#Create a smooth density plot of dollars per day from daydollars
plt.figure(figsize=(10,10))
sns.distplot(a=daydollars1970.dollars_per_day, hist=False);

# %%
#Create a smooth density plot of dollars per day for 1970 and 2010
plt.figure(figsize=(10,10))
sns.distplot(a=daydollars1970.dollars_per_day, hist=False, label='1970')
sns.distplot(a=daydollars2010.dollars_per_day, hist=False, label='2010');

# %%
#Make a scatter plot of infant_mortality versus dollars_per_day for countries in the African continent.
plt.figure(figsize=(20,20))
sns.scatterplot(x='infant_mortality',y='dollars_per_day',data=daydollars2010, hue='region',legend='full');
sns.scatterplot(x='infant_mortality',y='dollars_per_day',data=daydollars2010, hue='country',legend='full');
